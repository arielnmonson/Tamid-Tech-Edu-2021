# %%
import pandas as pd 
import numpy as py 
import matplotlib.pyplot as plt

# %%
trackers_df = pd.read_csv("Fitness_trackers.csv")
trackers_df
# Out:
#     Brand Name  Device Type             Model Name             Color  \
# 0       Xiaomi  FitnessBand           Smart Band 5             Black
# 1       Xiaomi  FitnessBand           Smart Band 4             Black
# 2       Xiaomi  FitnessBand               HMSH01GE             Black
# 3       Xiaomi  FitnessBand           Smart Band 5             Black
# 4       Xiaomi  FitnessBand                 Band 3             Black
# ..         ...          ...                    ...               ...
# 560     Huawei   Smartwatch            Watch 36456             Black
# 561     Huawei   Smartwatch  GT Fortuna-B19S Sport             Black
# 562      GOQii  FitnessBand                     HR             Black
# 563      GOQii  FitnessBand                  Vital             Black
# 564    FOSSIL    Smartwatch                 Gen 5E  Grey, Multicolor
#
#     Selling Price Original Price         Display  Rating (Out of 5)  \
# 0           2,499          2,999  AMOLED Display                4.1
# ...

# %%
trackers_df_cols = trackers_df.columns.str.replace("_", "")
trackers_df_cols
# Out:
# Index(['Brand Name', 'Device Type', 'Model Name', 'Color', 'Selling Price',
#        'Original Price', 'Display', 'Rating (Out of 5)', 'Strap Material',
#        'Average Battery Life (in days)', 'Reviews'],
#       dtype='object')

# %%
df2 = trackers_df[['Brand Name', 'Device Type', 'Model Name', 'Color', 'Selling Price', 
                  'Original Price', 'Rating (Out of 5)']]
df2
# Out:
#     Brand Name  Device Type             Model Name             Color  \
# 0       Xiaomi  FitnessBand           Smart Band 5             Black
# 1       Xiaomi  FitnessBand           Smart Band 4             Black
# 2       Xiaomi  FitnessBand               HMSH01GE             Black
# 3       Xiaomi  FitnessBand           Smart Band 5             Black
# 4       Xiaomi  FitnessBand                 Band 3             Black
# ..         ...          ...                    ...               ...
# 560     Huawei   Smartwatch            Watch 36456             Black
# 561     Huawei   Smartwatch  GT Fortuna-B19S Sport             Black
# 562      GOQii  FitnessBand                     HR             Black
# 563      GOQii  FitnessBand                  Vital             Black
# 564    FOSSIL    Smartwatch                 Gen 5E  Grey, Multicolor
#
#     Selling Price Original Price  Rating (Out of 5)
# 0           2,499          2,999                4.1
# ...

# %%
byregion = pd.crosstab(trackers_df["Original Price"], trackers_df["Selling Price"])
byregion
# Out:
# Selling Price   1,05,990  1,14,900  1,195  1,22,090  1,270  1,290  1,299  \
# Original Price
# 1,14,900               0         1      0         0      0      0      0
# 1,19,490               1         0      0         0      0      0      0
# 1,22,090               0         0      0         2      0      0      0
# 1,599                  0         0      0         0      1      0      0
# 1,799                  0         0      0         0      0      0      1
# ...                  ...       ...    ...       ...    ...    ...    ...
# 88,490                 0         0      0         0      0      0      0
# 9,990                  0         0      0         0      0      0      0
# 9,999                  0         0      0         0      0      0      0
# 96,390                 0         0      0         0      0      0      0
# 96,690                 0         0      0         0      0      0      0
#
# Selling Price   1,395  1,450  1,499  ...  8,999  81,990  84,490  86,990  \
# ...

# %%
trackers_df.describe()
# Out:
#        Rating (Out of 5)  Average Battery Life (in days)
# count         514.000000                      565.000000
# mean            4.229961                        9.026549
# std             0.390827                        7.868670
# min             2.000000                        1.000000
# 25%             4.025000                        2.000000
# 50%             4.300000                        7.000000
# 75%             4.500000                       14.000000
# max             5.000000                       45.000000

# %%
trackers_df.boxplot(column = ["Rating (Out of 5)", "Average Battery Life (in days)"])
# Out:
# <AxesSubplot:>

# %%
max_df = trackers_df.describe().max()
print(max_df)
# Out:
# Rating (Out of 5)                 514.0
# Average Battery Life (in days)    565.0
# dtype: float64

# %%
df2.loc[df2['Brand Name'].str.contains("FOSSIL")]
# Out:
#     Brand Name Device Type         Model Name             Color Selling Price  \
# 222    FOSSIL   Smartwatch   Gen 5 Carlyle HR             Black        15,995
# 223    FOSSIL   Smartwatch   Gen 5 Carlyle HR       Brown, Grey        14,995
# 224    FOSSIL   Smartwatch   Gen 5 Garrett HR            Silver        15,995
# 225    FOSSIL   Smartwatch  Gen 5 Julianna HR              Gold        18,495
# 226    FOSSIL   Smartwatch  Gen 5 Julianna HR             Black        18,995
# ..         ...         ...                ...               ...           ...
# 350    FOSSIL   Smartwatch           Sloan HR              Gold        21,995
# 351    FOSSIL   Smartwatch            Q GRANT             Black         6,995
# 352    FOSSIL   Smartwatch           Sport 41        Red, Green         9,995
# 353    FOSSIL   Smartwatch    FTW6006 Gold HR              Gold        21,995
# 564    FOSSIL   Smartwatch             Gen 5E  Grey, Multicolor        18,495
#
# ...

# %%
df.to_csv("brandname.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-7067cce00ea5> in <module>
# ----> 1 df.to_csv("brandname.csv")
#
# NameError: name 'df' is not defined
